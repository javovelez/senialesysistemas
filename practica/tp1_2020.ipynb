# %% [markdown]
# # Trabajo Práctico N$^\circ$1: Variable Compleja

# %% [markdown]
# Ejecutar antes que nada la siguiente celda que importa las libríeras necesarias

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Luego indicar si se desean guardar los gráficos de salida como imágenes .png y en que directorio

# %%
PLOT=1 # Setear a 1 para guardar o a 0 para no guardar
OUTPUT_PATH='/media/sf_asys/practica/2020/latex/tp1' # directorio de salida Fran
#OUTPUT_PATH='/Users/pm/OneDrive - frm.utn.edu.ar/ASyS/practica/2020/latex/tp1' # directorio de salida Pablo

# %% [markdown]
# Ej. 1.a)

# %%
z1=3-6j
z2=2+5j
print(z1 * z2)
# Out:
# (36+3j)

# %% [markdown]
# Ej. 2.b)

# %%
X = -2/5
Y = 0
plt.scatter(X,Y, color='blue')
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.grid('true')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.xlabel('x=Re(z)')
plt.ylabel('y=Im(z)')
if PLOT == 1:
    plt.savefig(OUTPUT_PATH+'/tp1_2b.png')
plt.show()

# %% [markdown]
# Ej. 6.c)

# %%
X = [1,0,-1,0]
Y = [0,1,0,-1]
plt.scatter(X,Y, color='blue')
plt.xlim([-2,2])
plt.ylim([-2,2])
plt.grid('true')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.xlabel('x=Re(z)')
plt.ylabel('y=Im(z)')
plt.axis('equal')
circle1=plt.Circle((0,0),1,color='r',fill=False)
plt.gcf().gca().add_artist(circle1)
if PLOT == 1:
    plt.savefig(OUTPUT_PATH+'/tp1_6c.png')
plt.show()

# %% [markdown]
# Ej. 9.a)

# %%
X = [148.4, 128.5, 74.21, 0, -74.21, -128.5, -148.1, -128.5]
Y = [0, 74.21, 128.5, 148.4, 128.5, 74.21, 0, -74.21]

tamanio = 2
fig= plt.figure(figsize=(tamanio*3,tamanio*3))
plt.scatter(X,Y, color='blue')
plt.xlim([-170,170])
plt.ylim([-170,170])
plt.grid('true')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.xlabel('x=Re(z)')
plt.ylabel('y=Im(z)')
if PLOT == 1:
    plt.savefig(OUTPUT_PATH+'/tp1_9a.png')
plt.show()

# %% [markdown]
# Ej. 16.a)

# %%
X = [1.76, 1.76, 1.76, 1.76, 1.76]
Y = [-11.5, -5.25, 1.03, 7.31, 13.6]

tamanio = 2
fig= plt.figure(figsize=(tamanio*3,tamanio*3))
plt.scatter(X,Y, color='blue')
plt.xlim([-15,15])
plt.ylim([-15,15])
plt.grid('true')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.xlabel('x=Re(z)')
plt.ylabel('y=Im(z)')
if PLOT == 1:
    plt.savefig(OUTPUT_PATH+'/tp1_16a.png')
plt.show()
