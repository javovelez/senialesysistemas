# %% [markdown]
# # Trabajo Práctico N$^\circ$3:

# %% [markdown]
# Ejecutar antes que nada la siguiente celda que importa las libríeras necesarias

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Luego indicar si se desean guardar los gráficos de salida como imágenes .png y en que directorio

# %%
PLOT=1 # Setear a 1 para guardar o a 0 para no guardar
OUTPUT_PATH='/media/sf_asys/practica/2020/latex/tp3' # directorio de salida Fran
#OUTPUT_PATH='/Users/pm/OneDrive - frm.utn.edu.ar/ASyS/practica/2020/latex/tp1' # directorio de salida Pablo

# %% [markdown]
# Ej. 9.a)

# %%
X = [-1,1,0,0]
Y = [0,0,1,-1]
plt.scatter(X,Y, color='blue')
plt.grid('true')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.xlabel('x=Re(z)')
plt.ylabel('y=Im(z)')
plt.axis('equal')
circle1=plt.Circle((-1,0),1,color='r',fill=False)
circle2=plt.Circle((0,1),1,color='b',fill=False)
plt.gcf().gca().add_artist(circle1)
plt.gcf().gca().add_artist(circle2)
plt.xlim([-3,3])
plt.ylim([-4,5])
if PLOT == 1:
    plt.savefig(OUTPUT_PATH+'/tp3_9ab.png')
plt.show()

# %% [markdown]
# Ej. 11.a)

# %%
X = [0]
Y = [1]
plt.scatter(X,Y, color='blue')
plt.grid('true')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.xlabel('x=Re(z)')
plt.ylabel('y=Im(z)')
plt.axis('equal')
circle=plt.Circle((-1,0),2,color='r',fill=False)
plt.gcf().gca().add_artist(circle)
circle=plt.Circle((2,0),1,color='b',fill=False)
plt.gcf().gca().add_artist(circle)
circle=plt.Circle((0,-1),3,color='g',fill=False)
plt.gcf().gca().add_artist(circle)
plt.xlim([-6,4])
plt.ylim([-8,6])
if PLOT == 1:
    plt.savefig(OUTPUT_PATH+'/tp3_11a.png')
plt.show()
